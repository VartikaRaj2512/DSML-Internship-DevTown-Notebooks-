# %% [markdown]
# # Revision

# %%
# DataFrame - Intro
# Creation of the DataFrame -
1. List
2. Another DataFrame
3. Dict
4. Series
5. Ndarray
# Columns - CRUD
Column Selection
Column Addition
Column Deletion - del, pop, drop

# %%
import pandas as pd

# %%
data = {"Apples":[102, 500, 250, 75],"Grapes":[50, 150, 90, 45]}
df = pd.DataFrame(data,index=["A", "B", "C", "D"])

# %%
df
# Out:
#    Apples  Grapes
# A     102      50
# B     500     150
# C     250      90
# D      75      45

# %%
df[['Grapes']]
# Out:
#    Grapes
# 0      50
# 1     150
# 2      90
# 3      45

# %%
df['Bananas'] = df['Grapes'] + 50

# %%
df['Pear'] = df['Bananas'] + 100
df['Mangoes'] = df['Pear'] + 500
df['Jackfruit'] = df['Grapes'] + 150
df['Strawberry'] = df['Jackfruit'] + 200
df['Oranges'] = df['Strawberry'] + 70

# %%
df
# Out:
#    Apples  Grapes  Bananas
# 0     102      50      100
# 1     500     150      200
# 2     250      90      140
# 3      75      45       95

# %%
df.drop(['Bananas'], axis=1, inplace=True)

# %%
df
# Out:
#    Apples  Grapes
# 0     102      50
# 1     500     150
# 2     250      90
# 3      75      45

# %% [markdown]
# # Row - CRUD

# %%
df
# Out:
#    Apples  Grapes  Bananas  Pear  Mangoes  Jackfruit  Strawberry  Oranges
# A     102      50      100   200      700        200         400      470
# B     500     150      200   300      800        300         500      570
# C     250      90      140   240      740        240         440      510
# D      75      45       95   195      695        195         395      465

# %% [markdown]
# * Row selection

# %%
loc & iloc

# %%
# loc -> Index_name
df.loc["A":"D"]
# Out:
#    Apples  Grapes  Bananas  Pear  Mangoes  Jackfruit  Strawberry  Oranges
# A     102      50      100   200      700        200         400      470
# B     500     150      200   300      800        300         500      570
# C     250      90      140   240      740        240         440      510
# D      75      45       95   195      695        195         395      465

# %%
# iloc -> index
df.iloc[2:3]
# Out:
#    Apples  Grapes  Bananas  Pear  Mangoes  Jackfruit  Strawberry  Oranges
# C     250      90      140   240      740        240         440      510

# %% [markdown]
# * Row Addition

# %%
student_marks = {"Name":["Rahul", "Rohit", "Venkat", "Sahil", "Ankita"],
                 "OS":[25, 75.5, 96, 0, 100],
                 "DBMS":[20, 80, 60, 50, 99]}

df1 = pd.DataFrame(student_marks)

# %%
df1
# Out:
#      Name     OS  DBMS
# 0   Rahul   25.0    20
# 1   Rohit   75.5    80
# 2  Venkat   96.0    60
# 3   Sahil    0.0    50
# 4  Ankita  100.0    99

# %%
data2 = {"Name":"Robby", "OS":60.5, "DBMS":55.5}

# %%
# 1st Method -> append()
df1 = df1.append(data2,ignore_index=True)

# %%
df1
# Out:
#      Name     OS  DBMS
# 0   Rahul   25.0  20.0
# 1   Rohit   75.5  80.0
# 2  Venkat   96.0  60.0
# 3   Sahil    0.0  50.0
# 4  Ankita  100.0  99.0
# 5   Robby   60.5  55.5

# %%
# 2nd Method -> concat()
data3 = {"Name":"Spiderman", "OS":90, "DBMS":100}
df3 = pd.DataFrame(data3,index=[0])

# arr.append(1)

# %%
df3
# Out:
#     Name    OS  DBMS
# 0  Venom  80.5    75

# %%
df1 = pd.concat([df1, df3])

# %%
df1
# Out:
#         Name     OS   DBMS
# 0      Venom   80.5   75.0
# 1      Rahul   25.0   20.0
# 2      Rohit   75.5   80.0
# 3     Venkat   96.0   60.0
# 4      Sahil    0.0   50.0
# 5     Ankita  100.0   99.0
# 6      Robby   60.5   55.5
# 7      Venom   80.5   75.0
# 0      Venom   80.5   75.0
# 0  Spiderman   90.0  100.0

# %%
df1.loc[[0]]
# Out:
#         Name    OS   DBMS
# 0      Venom  80.5   75.0
# 0      Venom  80.5   75.0
# 0  Spiderman  90.0  100.0

# %%
df1
# Out:
#         Name     OS   DBMS
# 0      Venom   80.5   75.0
# 1      Rahul   25.0   20.0
# 2      Rohit   75.5   80.0
# 3     Venkat   96.0   60.0
# 4      Sahil    0.0   50.0
# 5     Ankita  100.0   99.0
# 6      Robby   60.5   55.5
# 7      Venom   80.5   75.0
# 0      Venom   80.5   75.0
# 0  Spiderman   90.0  100.0

# %%
df1.loc[[4]]
# Out:
#     Name   OS  DBMS
# 4  Sahil  0.0  50.0

# %%
df1.iloc[5] = ["Hulk", 60]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-9a9d48c662fc> in <module>()
# ----> 1 df1.iloc[5] = ["Hulk", 60]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1751                     if len(ilocs) != len(value):
#    1752                         raise ValueError(
# -> 1753                             "Must have equal len keys and value "
#    1754                             "when setting with an iterable"
#    1755                         )
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
df1
# Out:
#        Name     OS   DBMS
# 0  Starlord   10.0    9.0
# 1     Rahul   25.0   20.0
# 2     Rohit   75.5   80.0
# 3    Venkat   96.0   60.0
# 4     Steve   67.0   23.0
# 5    Ankita  100.0   99.0
# 6     Robby   60.5   55.5
# 7     Venom   80.5   75.0
# 0    Vision  100.0  105.0
# 0    Vision  100.0  105.0

# %% [markdown]
# * Row Deletion

# %%
del, pop, drop

# %%
del df1.loc[[6]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-8116d43bb29d> in <module>()
# ----> 1 del df1.loc[[6]]
#
# AttributeError: __delitem__

# %%
df1.pop(df1.loc[[6]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-d8c0c119e653> in <module>()
# ----> 1 df1.pop(df1.loc[[6]])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in pop(self, item)
#    4369         3  monkey        NaN
#    4370         """
# -> 4371         return super().pop(item=item)
#    4372
#    4373     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in pop(self, item)
#     659
#     660     def pop(self, item: Label) -> Union["Series", Any]:
# --> 661         result = self[item]
#     662         del self[item]
#     663         if self.ndim == 2:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2891         # Do we have a (boolean) DataFrame?
#    2892         if isinstance(key, DataFrame):
# -> 2893             return self.where(key)
#    2894
#    2895         # Do we have a (boolean) 1d indexer?
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9009         other = com.apply_if_callable(other, self)
#    9010         return self._where(
# -> 9011             cond, other, inplace, axis, level, errors=errors, try_cast=try_cast
#    9012         )
#    9013
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8770                 for dt in cond.dtypes:
#    8771                     if not is_bool_dtype(dt):
# -> 8772                         raise ValueError(msg.format(dtype=dt))
#    8773         else:
#    8774             # GH#21947 we have an empty DataFrame/Series, could be object-dtype
#
# ValueError: Boolean array expected for the condition, not object

# %%
df1.loc.pop([6])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-a2dd32e6bf94> in <module>()
# ----> 1 df1.loc.pop([6])
#
# AttributeError: '_LocIndexer' object has no attribute 'pop'

# %%
df1.pop(6)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 6
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-3e7022c5d770> in <module>()
# ----> 1 df1.pop(6)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in pop(self, item)
#    4369         3  monkey        NaN
#    4370         """
# -> 4371         return super().pop(item=item)
#    4372
#    4373     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in pop(self, item)
#     659
#     660     def pop(self, item: Label) -> Union["Series", Any]:
# --> 661         result = self[item]
#     662         del self[item]
#     663         if self.ndim == 2:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 6

# %%
df1.drop(0, inplace=True)

# %%
df1
# Out:
#      Name     OS  DBMS
# 1   Rahul   25.0  20.0
# 2   Rohit   75.5  80.0
# 3  Venkat   96.0  60.0
# 4   Steve   67.0  23.0
# 5  Ankita  100.0  99.0
# 7   Venom   80.5  75.0

# %%
lis = [1,2,3,4,5,6,7]

# %% [markdown]
# * Data Exploration
# * Data Cleaning
# * Data Manipulation
# * Data Analysis

# %%
df1
# Out:
#      Name     OS  DBMS
# 1   Rahul   25.0  20.0
# 2   Rohit   75.5  80.0
# 3  Venkat   96.0  60.0
# 4   Steve   67.0  23.0
# 5  Ankita  100.0  99.0
# 7   Venom   80.5  75.0

# %% [markdown]
# # Data Exploration

# %%
df
# Out:
#    Apples  Grapes  Bananas  Pear  Mangoes  Jackfruit  Strawberry  Oranges
# A     102      50      100   200      700        200         400      470
# B     500     150      200   300      800        300         500      570
# C     250      90      140   240      740        240         440      510
# D      75      45       95   195      695        195         395      465

# %%
df1 10 millions # Population -> (Superset of all the Samples)
# Out:
#      Name     OS  DBMS
# 1   Rahul   25.0  20.0
# 2   Rohit   75.5  80.0
# 3  Venkat   96.0  60.0
# 4   Steve   67.0  23.0
# 5  Ankita  100.0  99.0
# 7   Venom   80.5  75.0

# %% [markdown]
# * head()

# %%
df1.head() # Sample (Subset of Population)
# Out:
#      Name     OS  DBMS
# 1   Rahul   25.0  20.0
# 2   Rohit   75.5  80.0
# 3  Venkat   96.0  60.0
# 4   Steve   67.0  23.0
# 5  Ankita  100.0  99.0

# %% [markdown]
# * tail()

# %%
df1.tail()
# Out:
#      Name     OS  DBMS
# 2   Rohit   75.5  80.0
# 3  Venkat   96.0  60.0
# 4   Steve   67.0  23.0
# 5  Ankita  100.0  99.0
# 7   Venom   80.5  75.0

# %%
df1.head(2)
# Out:
#     Name    OS  DBMS
# 1  Rahul  25.0  20.0
# 2  Rohit  75.5  80.0

# %%
df1.tail()
# Out:
#      Name     OS  DBMS
# 1   Rahul   25.0  20.0
# 2   Rohit   75.5  80.0
# 3  Venkat   96.0  60.0
# 4   Steve   67.0  23.0
# 5  Ankita  100.0  99.0
# 7   Venom   80.5  75.0

# %% [markdown]
# * dtypes

# %%
df1.dtypes
# Out:
# Name     object
# OS      float64
# DBMS    float64
# dtype: object

# %% [markdown]
# * empty

# %%
df1.empty
# Out:
# False

# %% [markdown]
# * ndim

# %%
df1.ndim
# Out:
# 2

# %% [markdown]
# * shape

# %%
df1.shape
# Out:
# (6, 3)

# %% [markdown]
# * size

# %%
df1.size
# Out:
# 18

# %% [markdown]
# * values

# %%
df1.keys
# Out:
# <bound method NDFrame.keys of      Name     OS  DBMS
# 1   Rahul   25.0  20.0
# 2   Rohit   75.5  80.0
# 3  Venkat   96.0  60.0
# 4   Steve   67.0  23.0
# 5  Ankita  100.0  99.0
# 7   Venom   80.5  75.0>

# %% [markdown]
# * describe

# %%
df1.describe()
# Out:
#                OS       DBMS
# count    6.000000   6.000000
# mean    74.000000  59.500000
# std     27.035162  31.979681
# min     25.000000  20.000000
# 25%     69.125000  32.250000
# 50%     78.000000  67.500000
# 75%     92.125000  78.750000
# max    100.000000  99.000000

# %% [markdown]
# * T

# %%
df1.T
# Out:
#           1      2       3      4       5      7
# Name  Rahul  Rohit  Venkat  Steve  Ankita  Venom
# OS       25   75.5      96     67     100   80.5
# DBMS     20     80      60     23      99     75

# %%
df1.iloc[1]
# Out:
# Name    Rohit
# OS       75.5
# DBMS       80
# Name: 2, dtype: object

# %%
df1
# Out:
#      Name     OS  DBMS
# 1   Rahul   25.0  20.0
# 2   Rohit   75.5  80.0
# 3  Venkat   96.0  60.0
# 4   Steve   67.0  23.0
# 5  Ankita  100.0  99.0
# 7   Venom   80.5  75.0

# %%
asd = df1.T

# %%
asd.iloc[1]
# Out:
# 1      25
# 2    75.5
# 3      96
# 4      67
# 5     100
# 7    80.5
# Name: OS, dtype: object

# %% [markdown]
# * sum()

# %%
df1.sum()
# Out:
# Name    RahulRohitVenkatSteveAnkitaVenom
# OS                                   444
# DBMS                                 357
# dtype: object

# %%
df1["OS"].sum()
# Out:
# 444.0

# %%
df1.sum(1) # 1 -> axis
# Out:
# 1     45.0
# 2    155.5
# 3    156.0
# 4     90.0
# 5    199.0
# 7    155.5
# dtype: float64

# %% [markdown]
# * mean()

# %%
df1.mean()
# Out:
# OS      74.0
# DBMS    59.5
# dtype: float64

# %%
df1.mean(1)
# Out:
# 1    22.50
# 2    77.75
# 3    78.00
# 4    45.00
# 5    99.50
# 7    77.75
# dtype: float64

# %%
df1
# Out:
#      Name     OS  DBMS
# 1   Rahul   25.0  20.0
# 2   Rohit   75.5  80.0
# 3  Venkat   96.0  60.0
# 4   Steve   67.0  23.0
# 5  Ankita  100.0  99.0
# 7   Venom   80.5  75.0

# %% [markdown]
# * median()

# %%
df1.median()
# Out:
# OS      78.0
# DBMS    67.5
# dtype: float64

# %%
df1.median(1)
# Out:
# 1    22.50
# 2    77.75
# 3    78.00
# 4    45.00
# 5    99.50
# 7    77.75
# dtype: float64

# %%
2+2
# Out:
# 4

# %%
2*2
# Out:
# 4

# %% [markdown]
# * mode()

# %%
df1
# Out:
#      Name     OS  DBMS
# 1   Rahul   25.0  20.0
# 2   Rohit   75.5  80.0
# 3  Venkat   96.0  60.0
# 4   Steve   67.0  23.0
# 5  Ankita  100.0  99.0
# 7   Venom   80.5  75.0

# %%
df1.mode()
# Out:
#      Name     OS  DBMS
# 0  Ankita   25.0  20.0
# 1   Rahul   67.0  23.0
# 2   Rohit   75.5  60.0
# 3   Steve   80.5  75.0
# 4  Venkat   96.0  80.0
# 5   Venom  100.0  99.0

# %%
df1.mode(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py:921: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'float'
#   warn(f"Unable to sort modes: {err}")
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py:921: UserWarning: Unable to sort modes: '<' not supported between instances of 'float' and 'str'
#   warn(f"Unable to sort modes: {err}")
#        0       1      2
# 1     20      25  Rahul
# 2     80   Rohit   75.5
# 3     96  Venkat     60
# 4  Steve      23     67
# 5    100  Ankita     99
# 7   80.5   Venom     75

# %% [markdown]
# * std

# %%
df1.std()
# Out:
# OS      27.035162
# DBMS    31.979681
# dtype: float64

# %%
df1.std(1)
# Out:
# 1     3.535534
# 2     3.181981
# 3    25.455844
# 4    31.112698
# 5     0.707107
# 7     3.889087
# dtype: float64

# %% [markdown]
# * min() & max()

# %%
df1.min()
# Out:
# Name    Ankita
# OS          25
# DBMS        20
# dtype: object

# %%
df1.max()
# Out:
# Name    Venom
# OS        100
# DBMS       99
# dtype: object

# %%
df1.min(1)
# Out:
# 1    20.0
# 2    75.5
# 3    60.0
# 4    23.0
# 5    99.0
# 7    75.0
# dtype: float64

# %%
df1.max(1)
# Out:
# 1     25.0
# 2     80.0
# 3     96.0
# 4     67.0
# 5    100.0
# 7     80.5
# dtype: float64

# %%
cumsum()
cumprod()
