# %%
a = int(input("Hello "))

# Error
# Work perfectly fine
# Out:
# Hello12

# %%
a = int(input())
b = int(input())
print((a+b) + (-a))


# 2
# 4
# Out:
# 4
# 2
# 2

# %%
a = input("input a number: ")
b = input("input a number: ")

ans = (a+b)

# Error
# Concatenate +
#  42
#  6
# Out:
# input a number: 4
# input a number: 2

# %%
ans
# Out:
# '42'

# %%
stri = "Python"
print(stri[1:4] + "does not make any sense")
# Out:
# ythdoes not make any sense

# %%
stri = "Welcome"
print(stri*9)
# WelcomeWelcome
#  Welcome Welcome
# Welcome
# Welcome
# Out:
# WelcomeWelcomeWelcomeWelcomeWelcomeWelcomeWelcomeWelcomeWelcome

# %%
stri = "examplei"
print(stri.center(4,'*'))

# exampl
# *exampole**
# **example*
# **********example*********
# Out:
# example

# %%
stri = "Typecasting:Type casting is a method used to change the variables/ values declared in a certain data type into a different data type to match the operation required to be performed by the code snippet."

# %%
stri.replace("b", "cat")
# Out:
# 'Typecasting:Type casting is a method used to change the variacatles/ values declared in a certain data type into a different data type to match the operation required to cate performed caty the code snippet.'

# %%
string = 'Hello, world.'
type(string)
# No
# Yes
# Out:
# str

# %%
"How to stop Thanos from snapping".endswith('g")
# Out:
# True

# %%
"How to stop Thanos from snapping".startswith("h")

# %%
 a = "welcome"
 "WELCOME" -> "welcome" ->"Welcome"
 print(((a.upper()).lower()).capitalize())
 print(a.upper().lower().capitalize())
# Out:
# Welcome
# Welcome

# %%
print(type(str(int(float(14.7)))))
# Out:
# <class 'str'>

# %%
a = 14.9

# %%
b = int(a)

# 14.9 int
#  14 int
#  15 int

# %%
b
# Out:
# 14

# %% [markdown]
# # Python Data Structures
#
# Organising, Structuring, Collection, Storing, Managing
#
#
#
# 1. List
# 2. Tuple
# 3. Dict
# 4. Set

# %% [markdown]
# # List
#
# 1. Python Data Structure
# 2. Changeable -> CRUD (C-> Create, R->Read, U->Update, D->Delete)
# 3. Store hetregenous data -> Different datatype
# 4. It allows duplicate value

# %%
lis = ["Potatoes",
"Tomatoes",
"Peas",
"Onion", 
"Cauliflower",
"Ladyfinger"]

# %%
lis
# Out:
# ['Potatoes', 'Tomatoes', 'Peas', 'Onion', 'Cauliflower', 'Ladyfinger']

# %%
print(lis[4])
lis[-2]
# Out:
# Cauliflower
# 'Cauliflower'

# %%
lis[]
# Out:
# ['Peas', 'Onion', 'Cauliflower', 'Ladyfinger']

# %%
stri = "Hello world"

# %%
stri[0:9:2]
# Out:
# 'Hello wor'

# %%
stri[0:9:2]
# Out:
# 'Hlowr'

# %%
CRUD

C -> Create
R -> Read
U -> Updation
D -> Delete

# %%
lis
# Out:
# ['Potatoes', 'Tomatoes', 'Peas', 'Onion', 'Cauliflower', 'Ladyfinger']

# %%
lis[2] = "Dhaniya"

# %%
lis
# Out:
# ['Potatoes', 'Tomatoes', 'Dhaniya', 'Onion', 'Cauliflower', 'Ladyfinger']

# %%
# Adding the list

append() -> Adds the elements into the list in the end
extend() -> Add the elements of two or more dictionary into one
insert() -> Add the elements into the list w.r.t to the provided index

# %%
lis.append("Milk")

# %%
lis.append("Biscuits")

# %%
lis.insert(1,"Pencil")

# %%
lis[1]
# Out:
# 'Pencil'

# %%
elec = ["Laptop", "Speaker", "Microphone"]
games = ["Temple Run", "COD","COC", "PubG"]

# %%
elec.extend(games)

# %%
elec
# Out:
# ['Laptop', 'Speaker', 'Microphone', 'Temple Run', 'COD', 'COC', 'PubG']

# %%
# To perform the deletion

remove(give me the name of the element)
pop(give me the index)
del -> delete it, just give me the index

# %%
elec.remove("Temple Run")

# %%
elec
# Out:
# ['Laptop', 'Speaker', 'Microphone', 'COD', 'COC', 'PubG']

# %%
elec.pop(-1)
# Out:
# 'PubG'

# %%
elec.pop()
# Out:
# 'COC'

# %%
elec
# Out:
# ['Laptop', 'Speaker', 'Microphone', 'COD']

# %%
num = [1,2,3,4,5,6,7]

# %%
num.remove(4)

# %%
num
# Out:
# [1, 2, 3, 5, 6, 7]

# %%
elec.remove()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-947772a56782> in <module>()
# ----> 1 elec.remove()
#
# TypeError: remove() takes exactly one argument (0 given)

# %%
listi = [[1,2,3],[4,5,6]]

# %%
listi[1][0]
# Out:
# 4

# %%
gdfhgd = []

# %%
listi[1].remove(5)

# %%
listi
# Out:
# [[1, 2, 3], [4, 6]]

# %%
elec
# Out:
# ['Laptop', 'Speaker', 'Microphone', 'COD']

# %%
# a.remove()
# len(a)
# del a[]

# %%
del elec[2]

# %%
elec
# Out:
# ['Laptop', 'Speaker', 'COD']

# %%
grades = [38, 44, 78,37,12,, 09,34,76,23]
# Out:
#   File "<ipython-input-84-a1e4ab99c542>", line 1
#     grades = [38, 44, 78,37,12,67,09,34,76,23]
#                                    ^
# SyntaxError: invalid token

# %%
grades = [34,57,98,24,56,21,67]

# %%
grades.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-385c61f75a2f> in <module>()
# ----> 1 grades.len()
#
# AttributeError: 'list' object has no attribute 'len'

# %%
len(grades)
# Out:
# 7

# %%
alph = ["Hello", "Worlid", "cat"]

# %%
max(alph)
# Out:
# 'cat'

# %%
min(grades)
# Out:
# 21

# %%
apl = ["z", "b", "f","d"]

# %%
apl.sort()

# %%
apl
# Out:
# ['b', 'd', 'f', 'z']

# %%
grades.sort(reverse=True)

# %%
grades
# Out:
# [98, 67, 57, 56, 34, 24, 21]

# %%
grades.reverse()

# %%
grades
# Out:
# [21, 24, 34, 56, 57, 67, 98]

# %%
basic list -> advanced list (list comprehension)

# %%
listi = []

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())
f = int(input())




listi.append(a)
listi.append(b)
listi.append(a)
listi.append(d)
listi.append(e)
# Out:
# 98
# 88
# 78
# 68
# 58
# 48

# %%
listi
# Out:
# [1, 2, 1, 4, 5, 98, 88, 98, 68, 58]

# %%
print("Hello world")
# Out:
# 'Hello world'

# %%
# Summary

1. CRUD
2. Append, LIst methods, extends, insert, remove, pop ,del, max, min, sort, indexing & slicing(more about)

# %%
lis = [1,2]
lis1 = [4,5]

# %%
lis+lis1
# Out:
# [1, 2, 4, 5]

# %%
a = "Hello Hola Hey Hi"
# Out:
# 'HloHl e '

# %%
a = [67,"Hey","98",98, 240,0.5,"0.6"]

# %%
a.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-2ed0d7de6146> in <module>()
# ----> 1 a.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
