# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing the dataset
#
# Link: https://drive.google.com/file/d/1y5DYn0dGoSbC22xowBq2d4po6h1JxcTQ/view

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/store_data.csv',
                 header=None)

# %% [markdown]
# # Data Analysis

# %%
df.head()
# Out:
#            shrimp    almonds     avocado  ... frozen smoothie spinach olive oil
# 0         burgers  meatballs        eggs  ...             NaN     NaN       NaN
# 1         chutney        NaN         NaN  ...             NaN     NaN       NaN
# 2          turkey    avocado         NaN  ...             NaN     NaN       NaN
# 3   mineral water       milk  energy bar  ...             NaN     NaN       NaN
# 4  low fat yogurt        NaN         NaN  ...             NaN     NaN       NaN
#
# [5 rows x 20 columns]

# %%
df.head()
# Out:
#               0          1           2   ...               17       18         19
# 0         shrimp    almonds     avocado  ...  frozen smoothie  spinach  olive oil
# 1        burgers  meatballs        eggs  ...              NaN      NaN        NaN
# 2        chutney        NaN         NaN  ...              NaN      NaN        NaN
# 3         turkey    avocado         NaN  ...              NaN      NaN        NaN
# 4  mineral water       milk  energy bar  ...              NaN      NaN        NaN
#
# [5 rows x 20 columns]

# %%
unique_values = set()
for col in df:
    unique_values.update(df[col])

# %%
len(unique_values)
# Out:
# 121

# %%
unique_values
# Out:
# {' asparagus',
#  'almonds',
#  'antioxydant juice',
#  'asparagus',
#  'avocado',
#  'babies food',
#  'bacon',
#  'barbecue sauce',
#  'black tea',
#  'blueberries',
#  'body spray',
#  'bramble',
#  'brownies',
#  'bug spray',
#  'burger sauce',
#  'burgers',
#  'butter',
#  'cake',
#  'candy bars',
#  'carrots',
#  'cauliflower',
#  'cereals',
#  'champagne',
#  'chicken',
#  'chili',
#  'chocolate',
#  'chocolate bread',
#  'chutney',
#  'cider',
#  'clothes accessories',
#  'cookies',
#  'cooking oil',
#  'corn',
#  'cottage cheese',
#  'cream',
#  'dessert wine',
#  'eggplant',
#  'eggs',
#  'energy bar',
#  'energy drink',
#  'escalope',
#  'extra dark chocolate',
#  'flax seed',
#  'french fries',
#  'french wine',
#  'fresh bread',
#  'fresh tuna',
#  'fromage blanc',
#  'frozen smoothie',
#  'frozen vegetables',
#  'gluten free bar',
#  'grated cheese',
#  'green beans',
#  'green grapes',
#  'green tea',
#  'ground beef',
#  'gums',
#  'ham',
#  'hand protein bar',
# ...

# %%
list(map(set,df.values))
# Out:
# [{'almonds',
#   'antioxydant juice',
#   'avocado',
#   'cottage cheese',
#   'energy drink',
#   'frozen smoothie',
#   'green grapes',
#   'green tea',
#   'honey',
#   'low fat yogurt',
#   'mineral water',
#   'olive oil',
#   'salad',
#   'salmon',
#   'shrimp',
#   'spinach',
#   'tomato juice',
#   'vegetables mix',
#   'whole weat flour',
#   'yams'},
#  {'burgers', 'eggs', 'meatballs', nan},
#  {'chutney', nan},
#  {'avocado', nan, 'turkey'},
#  {'energy bar', 'green tea', 'milk', 'mineral water', nan, 'whole wheat rice'},
#  {'low fat yogurt', nan},
#  {'french fries', nan, 'whole wheat pasta'},
#  {'light cream', nan, 'shallot', 'soup'},
#  {'frozen vegetables', 'green tea', nan, 'spaghetti'},
#  {'french fries', nan},
#  {'eggs', nan, 'pet food'},
#  {'cookies', nan},
#  {'burgers', 'cooking oil', 'eggs', 'mineral water', nan, 'turkey'},
#  {'champagne', 'cookies', nan, 'spaghetti'},
#  {'mineral water', nan, 'salmon'},
#  {'mineral water', nan},
#  {'chicken',
# ...

# %% [markdown]
# # ECLAT

# %%
# !pip install pyECLAT

# %%
from pyECLAT import ECLAT

# %%
eclat_instance = ECLAT(data=df, verbose=True)
# Out:
# ...
# 100%|██████████| 120/120 [00:00<00:00, 2468.02it/s]

# %%
eclat_instance.df_bin
# Out:
#       extra dark chocolate  protein bar  shampoo  ...  yams  spinach  bramble
# 0                        0            0        0  ...     1        1        0
# 1                        0            0        0  ...     0        0        0
# 2                        0            0        0  ...     0        0        0
# 3                        0            0        0  ...     0        0        0
# 4                        0            0        0  ...     0        0        0
# ...                    ...          ...      ...  ...   ...      ...      ...
# 7496                     0            0        0  ...     0        0        0
# 7497                     0            0        0  ...     0        0        0
# 7498                     0            0        0  ...     0        0        0
# 7499                     0            0        0  ...     0        0        0
# 7500                     0            0        0  ...     0        0        0
#
# [7501 rows x 120 columns]

# %%
eclat_instance.df_bin.columns
# Out:
# Index(['extra dark chocolate', 'protein bar', 'shampoo', 'turkey',
#        'whole wheat rice', 'oatmeal', 'avocado', 'chocolate bread',
#        'green beans', 'oil',
#        ...
#        'pasta', 'fresh bread', 'yogurt cake', 'fromage blanc',
#        'clothes accessories', 'sparkling water', 'white wine', 'yams',
#        'spinach', 'bramble'],
#       dtype='object', length=120)

# %%
eclat_instance.uniq_    #a list with all the names of the different items
# Out:
# [nan,
#  'extra dark chocolate',
#  'protein bar',
#  'shampoo',
#  'turkey',
#  'whole wheat rice',
#  'oatmeal',
#  'avocado',
#  'chocolate bread',
#  'green beans',
#  'oil',
#  'grated cheese',
#  'black tea',
#  'babies food',
#  'strawberries',
#  'cooking oil',
#  'antioxydant juice',
#  'chutney',
#  'tomatoes',
#  'hand protein bar',
#  'mint',
#  'energy bar',
#  'toothpaste',
#  'strong cheese',
#  'frozen vegetables',
#  'tomato juice',
#  'cookies',
#  'water spray',
#  'french wine',
#  'cauliflower',
#  'pickles',
#  'parmesan cheese',
#  'gums',
#  'rice',
#  'asparagus',
#  'spaghetti',
#  'ham',
#  'ground beef',
#  'almonds',
#  'burger sauce',
#  'milk',
#  'cream',
#  'cake',
#  'cottage cheese',
#  'olive oil',
#  'nonfat milk',
#  'shallot',
#  'zucchini',
#  'energy drink',
#  'champagne',
#  'green grapes',
#  'eggplant',
#  'mineral water',
#  'french fries',
#  'chicken',
#  'light cream',
#  'red wine',
#  'carrots',
#  'mayonnaise',
# ...

# %%
len(eclat_instance.uniq_ )
# Out:
# 121

# %%
get_ECLAT_indexes, get_ECLAT_supports = eclat_instance.fit_all(min_support=0.02,
                                                           separator=' & ',
                                                           verbose=True)
# Out:
# Combination 1 by 1
# 53it [00:00, 56.84it/s]
# Combination 2 by 2
# 1378it [00:13, 104.90it/s]
# Combination 3 by 3
# 23426it [03:47, 103.13it/s]
# Stopping in combination 3 by 3. All supports = 0.

# %%
get_ECLAT_indexes
# Out:
# {'burgers': [1,
#   12,
#   23,
#   49,
#   71,
#   81,
#   83,
#   89,
#   91,
#   94,
#   101,
#   102,
#   111,
#   118,
#   125,
#   133,
#   150,
#   156,
#   158,
#   165,
#   173,
#   181,
#   198,
#   224,
#   226,
#   246,
#   248,
#   254,
#   270,
#   301,
#   305,
#   317,
#   335,
#   396,
#   415,
#   439,
#   446,
#   456,
#   489,
#   508,
#   513,
#   518,
#   525,
#   552,
#   553,
#   579,
#   582,
#   585,
#   595,
#   618,
#   642,
#   667,
#   682,
#   691,
#   694,
#   698,
#   699,
#   723,
#   743,
#   744,
#   773,
#   781,
#   800,
#   810,
#   831,
#   847,
#   853,
#   872,
#   879,
#   881,
#   898,
#   905,
#   908,
#   936,
#   937,
#   956,
#   958,
#   973,
#   975,
#   989,
#   1005,
#   1016,
#   1017,
#   1021,
#   1031,
#   1041,
#   1044,
#   1064,
#   1074,
#   1097,
#   1101,
#   1105,
#   1139,
#   1149,
#   1159,
#   1183,
#   1204,
#   1231,
#   1237,
#   1263,
#   1284,
#   1289,
#   1295,
#   1306,
#   1310,
#   1314,
#   1317,
#   1342,
# ...

# %%
get_ECLAT_supports
# Out:
# {'almonds': 0.020397280362618318,
#  'avocado': 0.03332888948140248,
#  'brownies': 0.03372883615517931,
#  'burgers': 0.0871883748833489,
#  'butter': 0.030129316091187842,
#  'cake': 0.08105585921877083,
#  'cake & mineral water': 0.027463004932675644,
#  'cereals': 0.025729902679642713,
#  'champagne': 0.04679376083188908,
#  'chicken': 0.05999200106652446,
#  'chocolate': 0.1638448206905746,
#  'cookies': 0.08038928142914278,
#  'cooking oil': 0.0510598586855086,
#  'cooking oil & mineral water': 0.020130649246767097,
#  'cottage cheese': 0.03186241834422077,
#  'eggs': 0.17970937208372217,
#  'eggs & burgers': 0.02879616051193174,
#  'eggs & chocolate': 0.03319557392347687,
#  'eggs & green tea': 0.025463271563791495,
#  'eggs & pancakes': 0.021730435941874418,
#  'energy bar': 0.027063058258898813,
#  'energy drink': 0.026663111585121985,
#  'escalope': 0.0793227569657379,
#  'french fries': 0.1709105452606319,
#  'french fries & burgers': 0.021997067057725635,
# ...
