# %%
x= 46
y= 98
x,y = 46,98

# %%
x,y = y,x

# %%
x,y
# Out:
# (98, 46)

# %%
1987 >OR= 1907
# Out:
# True

# %%
a = 2(3)
b = 3(3)
c = 3

# %%
a=b
b=c

# %%
c is not a
# Out:
# True

# %% [markdown]
# # Revision

# %%
a = "12"

# %%
type(a)
# Out:
# str

# %%
print("12"*3H)

# 1212
# Error
# Out:
#   File "<ipython-input-73-e03aaba2c278>", line 1
#     print("12"*3H)
#                 ^
# SyntaxError: invalid syntax

# %%
var = 12
vari = 14
vary = 23

# %%
print(var + vari - vary)

var + vari = 12 + 14 = 26 - 23 =3
vari - vary = 14 - 23 = -9 = 12 + (-9) = 12- 9 = 3
# 3

+ - = -
+ + = +
- + = -
- - = +
# Out:
# 3

# %%
is -> ==
not -> !

# %%
a,b = 12,12

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
a != b
# Out:
# False

# %%
@shape = 12

name = @shape + 2
name
# Out:
#   File "<ipython-input-81-29bb962057e0>", line 1
#     @shape = 12
#            ^
# SyntaxError: invalid syntax

# %%
print("python")
__
dkfgjdfkgfkbnfgo
dlgjfkblfgbkfgbfkbf
__

# %% [markdown]
# # String methods

# %%
string1 = "today is saturday"

# %%
# [] -> Square Brackets
# {} -> Curly Brackets
# () -> Round Brackets

# %% [markdown]
# *   captialize()

# %%
string1 = string1.capitalize()

# %%
string1
# Out:
# 'Today is saturday'

# %% [markdown]
# *   len()

# %%
len(string1)
# Out:
# 17

# %% [markdown]
# *   center()

# %%
######sahil######

# %%
# variable.center(len, char)

# %%
asd = string1.center(10)

# %%
asdi = "Apple"

# %%
asdi.center(20,"*")
# Out:
# '*******Apple********'

# %% [markdown]
# *   endswith()

# %%
# 1 - True
# 2 - False

# %%
# string1.endswith(value, start, end)
# Out:
# 'Today is saturday'

# %%
string1.endswith("y")
# Out:
# True

# %%
string1.endswith("y",3,9)
# Out:
# False

# %%
string1
# Out:
# 'Today is saturday'

# %% [markdown]
# 1.   startswith()

# %%
# string1.startswith(value, start, end)

# %%
tar = "Welcome to the world"

# %%
tar.startswith("W")
# Out:
# True

# %% [markdown]
# 1.   count()

# %%
tar
# Out:
# 'Welcome to the world'

# %%
tar.count("o")
# Out:
# 3

# %% [markdown]
# 1. upper() & lower()

# %%
a -> lowercase
A -> Uppercase

# %%
tar.upper()
# Out:
# 'WELCOME TO THE WORLD'

# %%
tar = tar.lower()
# Out:
# 'welcome to the world'

# %%
tar
# Out:
# 'Welcome to the world'

# %% [markdown]
# # Input

# %%
a = int(input("Enter the value of a "))
b = int(input("Enter the value of b "))
# Out:
# Enter the value of a 12
# Enter the value of b 67

# %%
type(b)
# Out:
# int

# %%
a+b

# Error
# 1245
# 57
# Out:
# 57

# %%
input() -> String

# %% [markdown]
# # Typecasting

# %%
age = "22"

# %%
type(int(age))
# Out:
# int

# %% [markdown]
# # Python Data Structures

# %%
# Arrays, Stack, Queue, Linked Lits, Hashing, Graphs, Trees

1. List - [1,2,3,4,5,6,7,7,7,7,76,6,6,6,11,1,2,2,2]
2. Tuple - ()
3. Dict - {key:value}
Computer: A machine that understands humans
4. Set - {1,2,3,4,5,6,7}

if elif else -> Conditional Statement
For
while
try except

project =

# %%
{dgjgidjghfdighdig}

# %%
a = 4

# %%
a
# Out:
# 4

# %%
email = "dear professor,......."
# "Dear professor..."

# %%
email = email.capitalize()

# %%
email
# Out:
# 'Dear professor,.......'

# %%
email = email.upper()

# %%
email
# Out:
# 'DEAR PROFESSOR,.......'

# %%
email
# Out:
# 'DEAR PROFESSOR,.......'

# %%
email.upper()[5:14]

# Error

# DEAR professor,.......
# Out:
# 'PROFESSOR'

# %%
email[5:14].
#  Immutable -> They never ever supports the item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-e6ae1d129a9a> in <module>()
# ----> 1 email[5:14] = email[0:9].lower()
#
# TypeError: 'str' object does not support item assignment

# %%
email.lower()
# Out:
# 'DEAR PROFESSOR,.......'

# %%
lower(email[5:14])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-157-15020ed2ddb8> in <module>()
# ----> 1 lower(email[5:14])
#
# NameError: name 'lower' is not defined
