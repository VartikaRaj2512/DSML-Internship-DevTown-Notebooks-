# %% [markdown]
# # Data Cleaning & Data Manipulation

# %%
import pandas as pd
import numpy as np

# %%
data1 = np.random.randn(10,3)
data2 = np.random.randn(7,3)

# %%
df1 = pd.DataFrame(data1, columns=["Col1", "Col2", "Col3"])
df2 = pd.DataFrame(data2, columns=["Col1", "Col2", "Col3"])

# %%
df1
# Out:
#        Col1      Col2      Col3
# 0  0.625766 -1.161112 -0.362673
# 1 -1.479641 -0.485604  0.369964
# 2  1.472300  0.194014  1.405674
# 3 -0.458088 -0.608173 -2.229785
# 4 -0.768349 -0.834313  0.426521
# 5 -0.919398 -3.872343 -0.636717
# 6  0.149572 -0.102499  0.629445
# 7 -0.738339  0.131016  0.425828
# 8 -0.164048  2.951231 -0.820013
# 9 -1.339718  1.032922  0.241880

# %%
df2
# Out:
#        Col1      Col2      Col3
# 0  1.970920  1.543224 -0.210029
# 1  0.428057 -0.515374 -0.214166
# 2  0.788745 -0.667020 -0.835686
# 3  0.031070 -2.038181 -1.426491
# 4  0.071847 -0.311295 -0.437778
# 5  0.473463  0.275466 -1.378353
# 6 -1.278267  0.030640 -0.531510

# %%
df3 = df1 + df2
df3 = df[1] + df[2]

# %%
df3 = pd.concat([df1,df2], ignore_index=True)

# %%
df3
# Out:
#         Col1      Col2      Col3
# 0   0.625766 -1.161112 -0.362673
# 1  -1.479641 -0.485604  0.369964
# 2   1.472300  0.194014  1.405674
# 3  -0.458088 -0.608173 -2.229785
# 4  -0.768349 -0.834313  0.426521
# 5  -0.919398 -3.872343 -0.636717
# 6   0.149572 -0.102499  0.629445
# 7  -0.738339  0.131016  0.425828
# 8  -0.164048  2.951231 -0.820013
# 9  -1.339718  1.032922  0.241880
# 10  1.970920  1.543224 -0.210029
# 11  0.428057 -0.515374 -0.214166
# 12  0.788745 -0.667020 -0.835686
# 13  0.031070 -2.038181 -1.426491
# 14  0.071847 -0.311295 -0.437778
# 15  0.473463  0.275466 -1.378353
# 16 -1.278267  0.030640 -0.531510

# %%
for i in df3.Col3:
  print(i)
# Out:
# -0.3626726709462253
# 0.36996421736534535
# 1.4056744010507538
# -2.22978461208194
# 0.4265205803260593
# -0.636716839306351
# 0.6294445088973881
# 0.4258279310879293
# -0.820013136226335
# 0.2418802398362948
# -0.21002913483490748
# -0.21416552318063878
# -0.8356857795524385
# -1.4264912541653745
# -0.43777799917028215
# -1.3783529311808196
# -0.5315099448187365

# %% [markdown]
# * iteritems

# %%
# For columns
for key,value in df3.iteritems():
  print(key,value)
# Out:
# Col1 0     0.625766
# 1    -1.479641
# 2     1.472300
# 3    -0.458088
# 4    -0.768349
# 5    -0.919398
# 6     0.149572
# 7    -0.738339
# 8    -0.164048
# 9    -1.339718
# 10    1.970920
# 11    0.428057
# 12    0.788745
# 13    0.031070
# 14    0.071847
# 15    0.473463
# 16   -1.278267
# Name: Col1, dtype: float64
# Col2 0    -1.161112
# 1    -0.485604
# 2     0.194014
# 3    -0.608173
# 4    -0.834313
# 5    -3.872343
# 6    -0.102499
# 7     0.131016
# 8     2.951231
# 9     1.032922
# 10    1.543224
# 11   -0.515374
# 12   -0.667020
# 13   -2.038181
# 14   -0.311295
# 15    0.275466
# 16    0.030640
# Name: Col2, dtype: float64
# Col3 0    -0.362673
# 1     0.369964
# 2     1.405674
# 3    -2.229785
# 4     0.426521
# 5    -0.636717
# 6     0.629445
# 7     0.425828
# 8    -0.820013
# 9     0.241880
# 10   -0.210029
# 11   -0.214166
# 12   -0.835686
# 13   -1.426491
# 14   -0.437778
# 15   -1.378353
# 16   -0.531510
# Name: Col3, dtype: float64

# %% [markdown]
# * iterrows()

# %%
# For rows
for index,row in df3.iterrows():
  print(index, row)
# Out:
# 0 Col1    0.625766
# Col2   -1.161112
# Col3   -0.362673
# Name: 0, dtype: float64
# 1 Col1   -1.479641
# Col2   -0.485604
# Col3    0.369964
# Name: 1, dtype: float64
# 2 Col1    1.472300
# Col2    0.194014
# Col3    1.405674
# Name: 2, dtype: float64
# 3 Col1   -0.458088
# Col2   -0.608173
# Col3   -2.229785
# Name: 3, dtype: float64
# 4 Col1   -0.768349
# Col2   -0.834313
# Col3    0.426521
# Name: 4, dtype: float64
# 5 Col1   -0.919398
# Col2   -3.872343
# Col3   -0.636717
# Name: 5, dtype: float64
# 6 Col1    0.149572
# Col2   -0.102499
# Col3    0.629445
# Name: 6, dtype: float64
# 7 Col1   -0.738339
# Col2    0.131016
# Col3    0.425828
# Name: 7, dtype: float64
# 8 Col1   -0.164048
# Col2    2.951231
# Col3   -0.820013
# Name: 8, dtype: float64
# 9 Col1   -1.339718
# Col2    1.032922
# Col3    0.241880
# Name: 9, dtype: float64
# 10 Col1    1.970920
# Col2    1.543224
# Col3   -0.210029
# Name: 10, dtype: float64
# 11 Col1    0.428057
# Col2   -0.515374
# Col3   -0.214166
# Name: 11, dtype: float64
# 12 Col1    0.788745
# Col2   -0.667020
# Col3   -0.835686
# Name: 12, dtype: float64
# 13 Col1    0.031070
# Col2   -2.038181
# Col3   -1.426491
# Name: 13, dtype: float64
# 14 Col1    0.071847
# Col2   -0.311295
# Col3   -0.437778
# Name: 14, dtype: float64
# 15 Col1    0.473463
# Col2    0.275466
# Col3   -1.378353
# Name: 15, dtype: float64
# 16 Col1   -1.278267
# Col2    0.030640
# Col3   -0.531510
# Name: 16, dtype: float64

# %% [markdown]
# * Sort - sort_index()

# %%
unsorted_df = pd.DataFrame(np.random.randn(10,3), 
                           index = [5,7,3,9,2,1,9,11,21,4],
                           columns = ['Col1', 'Col2', 'Col3'])

# %%
unsorted_df
# Out:
#         Col1      Col2      Col3
# 5   0.774385 -0.275355 -1.309678
# 7  -1.313731  0.437636  0.426441
# 3   0.102599 -0.327263  0.548485
# 9  -1.826708 -0.449267  0.257734
# 2   1.450232 -0.474567  0.363058
# 1  -1.150531  1.213036 -1.014364
# 9   0.755127 -0.596685 -0.448257
# 11  0.490750 -0.639434  2.036461
# 21 -0.976040 -0.419706  1.022377
# 4  -0.166359 -0.995609  0.405400

# %%
unsorted_df.sort_index()
# Out:
#         Col1      Col2      Col3
# 1  -1.150531  1.213036 -1.014364
# 2   1.450232 -0.474567  0.363058
# 3   0.102599 -0.327263  0.548485
# 4  -0.166359 -0.995609  0.405400
# 5   0.774385 -0.275355 -1.309678
# 7  -1.313731  0.437636  0.426441
# 9  -1.826708 -0.449267  0.257734
# 9   0.755127 -0.596685 -0.448257
# 11  0.490750 -0.639434  2.036461
# 21 -0.976040 -0.419706  1.022377

# %%
unsorted_df.sort_index(ascending=False)
# Out:
#         Col1      Col2      Col3
# 21 -0.976040 -0.419706  1.022377
# 11  0.490750 -0.639434  2.036461
# 9  -1.826708 -0.449267  0.257734
# 9   0.755127 -0.596685 -0.448257
# 7  -1.313731  0.437636  0.426441
# 5   0.774385 -0.275355 -1.309678
# 4  -0.166359 -0.995609  0.405400
# 3   0.102599 -0.327263  0.548485
# 2   1.450232 -0.474567  0.363058
# 1  -1.150531  1.213036 -1.014364

# %%
unsorted_df.sort_index(axis=1)
# Out:
#         Col1      Col2      Col3
# 5   0.774385 -0.275355 -1.309678
# 7  -1.313731  0.437636  0.426441
# 3   0.102599 -0.327263  0.548485
# 9  -1.826708 -0.449267  0.257734
# 2   1.450232 -0.474567  0.363058
# 1  -1.150531  1.213036 -1.014364
# 9   0.755127 -0.596685 -0.448257
# 11  0.490750 -0.639434  2.036461
# 21 -0.976040 -0.419706  1.022377
# 4  -0.166359 -0.995609  0.405400

# %%
unsorted_df.sort_index(axis=1, ascending=False)
# Out:
#         Col3      Col2      Col1
# 5  -1.309678 -0.275355  0.774385
# 7   0.426441  0.437636 -1.313731
# 3   0.548485 -0.327263  0.102599
# 9   0.257734 -0.449267 -1.826708
# 2   0.363058 -0.474567  1.450232
# 1  -1.014364  1.213036 -1.150531
# 9  -0.448257 -0.596685  0.755127
# 11  2.036461 -0.639434  0.490750
# 21  1.022377 -0.419706 -0.976040
# 4   0.405400 -0.995609 -0.166359

# %%
[6,5,8,2,5,9,2,1].sort() -> Timsort

# %% [markdown]
# * sort_values()

# %%
df = pd.DataFrame({"Apples":[50,95, 105,75],"Grapes":[110,45,99,0]})

# %%
df
# Out:
#    Apples  Grapes
# 0      50     110
# 1      95      45
# 2     105      99
# 3      75       0

# %%
df.sort_values(by=['Apples', 'Grapes'])
# Out:
#    Apples  Grapes
# 0      50     110
# 3      75       0
# 1      95      45
# 2     105      99

# %%
df.sort_values(by=['Apples', 'Grapes'],kind='mergesort')
1. Quicksort
2. Mergesort
3. Heapsort
# Out:
#    Apples  Grapes
# 0      50     110
# 3      75       0
# 1      95      45
# 2     105      99

# %% [markdown]
# * Stats - Advanced

# %%
df3
# Out:
#         Col1      Col2      Col3
# 0   0.625766 -1.161112 -0.362673
# 1  -1.479641 -0.485604  0.369964
# 2   1.472300  0.194014  1.405674
# 3  -0.458088 -0.608173 -2.229785
# 4  -0.768349 -0.834313  0.426521
# 5  -0.919398 -3.872343 -0.636717
# 6   0.149572 -0.102499  0.629445
# 7  -0.738339  0.131016  0.425828
# 8  -0.164048  2.951231 -0.820013
# 9  -1.339718  1.032922  0.241880
# 10  1.970920  1.543224 -0.210029
# 11  0.428057 -0.515374 -0.214166
# 12  0.788745 -0.667020 -0.835686
# 13  0.031070 -2.038181 -1.426491
# 14  0.071847 -0.311295 -0.437778
# 15  0.473463  0.275466 -1.378353
# 16 -1.278267  0.030640 -0.531510

# %%
df4 = df3.drop([8,9,10,11,12,13,14,15,16])

# %%
df3
# Out:
#         Col1      Col2      Col3
# 0   0.625766 -1.161112 -0.362673
# 1  -1.479641 -0.485604  0.369964
# 2   1.472300  0.194014  1.405674
# 3  -0.458088 -0.608173 -2.229785
# 4  -0.768349 -0.834313  0.426521
# 5  -0.919398 -3.872343 -0.636717
# 6   0.149572 -0.102499  0.629445
# 7  -0.738339  0.131016  0.425828
# 8  -0.164048  2.951231 -0.820013
# 9  -1.339718  1.032922  0.241880
# 10  1.970920  1.543224 -0.210029
# 11  0.428057 -0.515374 -0.214166
# 12  0.788745 -0.667020 -0.835686
# 13  0.031070 -2.038181 -1.426491
# 14  0.071847 -0.311295 -0.437778
# 15  0.473463  0.275466 -1.378353
# 16 -1.278267  0.030640 -0.531510

# %%
df4
# Out:
#        Col1      Col2      Col3
# 0  0.625766 -1.161112 -0.362673
# 1 -1.479641 -0.485604  0.369964
# 2  1.472300  0.194014  1.405674
# 3 -0.458088 -0.608173 -2.229785
# 4 -0.768349 -0.834313  0.426521
# 5 -0.919398 -3.872343 -0.636717
# 6  0.149572 -0.102499  0.629445
# 7 -0.738339  0.131016  0.425828

# %% [markdown]
# * Covariance -> cov()

# %%
df4.Col2
# Out:
# 0   -1.161112
# 1   -0.485604
# 2    0.194014
# 3   -0.608173
# 4   -0.834313
# 5   -3.872343
# 6   -0.102499
# 7    0.131016
# Name: Col2, dtype: float64

# %%
df4['Col2']
# Out:
# 0   -1.161112
# 1   -0.485604
# 2    0.194014
# 3   -0.608173
# 4   -0.834313
# 5   -3.872343
# 6   -0.102499
# 7    0.131016
# Name: Col2, dtype: float64

# %%
df4.Col2.cov(df4['Col3'])
# Out:
# 0.5707245450085268

# %%
df4.cov
# Out:
# <bound method DataFrame.cov of        Col1      Col2      Col3
# 0  0.625766 -1.161112 -0.362673
# 1 -1.479641 -0.485604  0.369964
# 2  1.472300  0.194014  1.405674
# 3 -0.458088 -0.608173 -2.229785
# 4 -0.768349 -0.834313  0.426521
# 5 -0.919398 -3.872343 -0.636717
# 6  0.149572 -0.102499  0.629445
# 7 -0.738339  0.131016  0.425828>

# %% [markdown]
# * Correlation - corr

# %%
df4['Col2'].corr(df4['Col3'])
# Out:
# 0.397813910920498

# %%
df4.corr
# Out:
# <bound method DataFrame.corr of        Col1      Col2      Col3
# 0  0.625766 -1.161112 -0.362673
# 1 -1.479641 -0.485604  0.369964
# 2  1.472300  0.194014  1.405674
# 3 -0.458088 -0.608173 -2.229785
# 4 -0.768349 -0.834313  0.426521
# 5 -0.919398 -3.872343 -0.636717
# 6  0.149572 -0.102499  0.629445
# 7 -0.738339  0.131016  0.425828>

# %% [markdown]
# # Data Cleaning

# %%
df = pd.DataFrame(np.random.randn(5,3),
                  index = ["A", "C", "E", "F", "G"],
                  columns = ["Col1", "Col2", "Col3"])

# %%
df
# Out:
#        Col1      Col2      Col3
# A -0.266604 -0.404436  0.459950
# C -0.601140  1.469662 -2.278960
# E -0.128843 -0.817817  0.348934
# F  0.610204 -0.764480  1.587221
# G -0.471289  1.257911  0.196935

# %%
df = df.reindex(["A", "B", "C", "D", "E", "F", "G", "H"])

# %%
df
# Out:
#        Col1      Col2      Col3
# A -0.266604 -0.404436  0.459950
# B       NaN       NaN       NaN
# C -0.601140  1.469662 -2.278960
# D       NaN       NaN       NaN
# E -0.128843 -0.817817  0.348934
# F  0.610204 -0.764480  1.587221
# G -0.471289  1.257911  0.196935
# H       NaN       NaN       NaN

# %% [markdown]
# * isnull()

# %%
df.isnull()
# Out:
#     Col1   Col2   Col3
# A  False  False  False
# B   True   True   True
# C  False  False  False
# D   True   True   True
# E  False  False  False
# F  False  False  False
# G  False  False  False
# H   True   True   True

# %%
df.isnull().sum()
# Out:
# Col1    3
# Col2    3
# Col3    3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 9

# %%
df['Col1'].isnull()
# Out:
# A    False
# B     True
# C    False
# D     True
# E    False
# F    False
# G    False
# H     True
# Name: Col1, dtype: bool

# %%
df.loc["G"].isnull()
# Out:
# Col1    False
# Col2    False
# Col3    False
# Name: G, dtype: bool

# %% [markdown]
# * isna()

# %%
df.isna()
# Out:
#     Col1   Col2   Col3
# A  False  False  False
# B   True   True   True
# C  False  False  False
# D   True   True   True
# E  False  False  False
# F  False  False  False
# G  False  False  False
# H   True   True   True

# %%
df.isna().dtypes
# Out:
# Date         bool
# Open         bool
# High         bool
# Low          bool
# Close        bool
# Adj Close    bool
# Volume       bool
# dtype: object

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# * notnull()

# %%
df.notnull()
# Out:
#     Col1   Col2   Col3
# A   True   True   True
# B  False  False  False
# C   True   True   True
# D  False  False  False
# E   True   True   True
# F   True   True   True
# G   True   True   True
# H  False  False  False

# %%
df.notnull().sum(1)
# Out:
# A    3
# B    0
# C    3
# D    0
# E    3
# F    3
# G    3
# H    0
# dtype: int64

# %%
df.count()
# Out:
# Col1    5
# Col2    5
# Col3    5
# dtype: int64

# %% [markdown]
# * Clean Missing (NaN) Values

# %%
df
# Out:
#        Col1      Col2      Col3
# A -0.266604 -0.404436  0.459950
# B       NaN       NaN       NaN
# C -0.601140  1.469662 -2.278960
# D       NaN       NaN       NaN
# E -0.128843 -0.817817  0.348934
# F  0.610204 -0.764480  1.587221
# G -0.471289  1.257911  0.196935
# H       NaN       NaN       NaN

# %% [markdown]
# * fillna()

# %%
df.fillna(10)
# Out:
#         Col1       Col2       Col3
# A  -0.266604  -0.404436   0.459950
# B  10.000000  10.000000  10.000000
# C  -0.601140   1.469662  -2.278960
# D  10.000000  10.000000  10.000000
# E  -0.128843  -0.817817   0.348934
# F   0.610204  -0.764480   1.587221
# G  -0.471289   1.257911   0.196935
# H  10.000000  10.000000  10.000000

# %%
# Forward Method - pad/ffill
# Backward Method - bfill/backfill

# %%
df
# Out:
#        Col1      Col2      Col3
# A -0.266604 -0.404436  0.459950
# B       NaN       NaN       NaN
# C -0.601140  1.469662 -2.278960
# D       NaN       NaN       NaN
# E -0.128843 -0.817817  0.348934
# F  0.610204 -0.764480  1.587221
# G -0.471289  1.257911  0.196935
# H       NaN       NaN       NaN

# %%
df.fillna(method='pad')
# Out:
#        Col1      Col2      Col3
# A -0.266604 -0.404436  0.459950
# B -0.266604 -0.404436  0.459950
# C -0.601140  1.469662 -2.278960
# D -0.601140  1.469662 -2.278960
# E -0.128843 -0.817817  0.348934
# F  0.610204 -0.764480  1.587221
# G -0.471289  1.257911  0.196935
# H -0.471289  1.257911  0.196935

# %%
df.fillna(method='pad',axis=1)
# Out:
#        Col1      Col2      Col3
# A -0.266604 -0.404436  0.459950
# B       NaN       NaN       NaN
# C -0.601140  1.469662 -2.278960
# D       NaN       NaN       NaN
# E -0.128843 -0.817817  0.348934
# F  0.610204 -0.764480  1.587221
# G -0.471289  1.257911  0.196935
# H       NaN       NaN       NaN

# %%
df.fillna(method='bfill')
# Out:
#        Col1      Col2      Col3
# A -0.266604 -0.404436  0.459950
# B -0.601140  1.469662 -2.278960
# C -0.601140  1.469662 -2.278960
# D -0.128843 -0.817817  0.348934
# E -0.128843 -0.817817  0.348934
# F  0.610204 -0.764480  1.587221
# G -0.471289  1.257911  0.196935
# H       NaN       NaN       NaN

# %% [markdown]
# * dropna()

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [A, B, C, D, E, F, G, H]

# %% [markdown]
# * Replacing values - replace()

# %%
df
# Out:
#        Col1      Col2      Col3
# A -0.266604 -0.404436  0.459950
# B       NaN       NaN       NaN
# C -0.601140  1.469662 -2.278960
# D       NaN       NaN       NaN
# E -0.128843 -0.817817  0.348934
# F  0.610204 -0.764480  1.587221
# G -0.471289  1.257911  0.196935
# H       NaN       NaN       NaN

# %%
df.replace({1.046703:100.0, 2.479047:200.0})
# Out:
#        Col1      Col2      Col3
# A -0.115313  1.048668  1.046703
# B       NaN       NaN       NaN
# C  0.961052 -1.713892 -0.461323
# D       NaN       NaN       NaN
# E -0.636107  2.479047 -0.575382
# F -2.516664 -0.453648 -0.739120
# G  0.750485 -0.982442 -0.048721
# H       NaN       NaN       NaN

# %%
df.replace({50:90, 99:245})
# Out:
#    Apples  Grapes
# 0      90     110
# 1      95      45
# 2     105     245
# 3      75       0

# %%
df
# Out:
#    Apples  Grapes
# 0      50     110
# 1      95      45
# 2     105      99
# 3      75       0

# %%
df.Apples.loc[2] = 500

# %%
df
# Out:
#    Apples  Grapes
# 0      50     110
# 1      95      45
# 2     500      99
# 3      75       0

# %%
df.Grapes.loc[2] = 299
df.loc[____, ___]

# %%
df
# Out:
#    Apples  Grapes
# 0      50     110
# 1      95      45
# 2     500     299
# 3      75       0

# %%
df.Apples.loc[3] = 50

# %%
df
# Out:
#    Apples  Grapes
# 0      50     110
# 1      95      45
# 2     500     299
# 3      50       0

# %% [markdown]
# # Handle Duplicates Values

# %% [markdown]
# * Check the cuplicate values - duplicated()

# %%
df.duplicated(subset=['Apples'])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %% [markdown]
# * Remove duplicate values -> drop_duplicates()

# %%
df
# Out:
#    Apples  Grapes
# 0      50     110
# 1      95      45
# 2     500     299
# 3      50       0

# %%
df.drop_duplicates(subset=['Apples'])
# Out:
#    Apples  Grapes
# 0      50     110
# 1      95      45
# 2     500     299

# %% [markdown]
# Import/Export a dataset

# %%
data = "https://raw.githubusercontent.com/ShapeAI/Python-for-Data-Science-/master/stocks.csv"
df = pd.read_csv(data)

# %%
df
# Out:
#             Date        Open        High  ...       Close   Adj Close    Volume
# 0     2004-08-19   49.676899   51.693783  ...   49.845802   49.845802  44994500
# 1     2004-08-20   50.178635   54.187561  ...   53.805050   53.805050  23005800
# 2     2004-08-23   55.017166   56.373344  ...   54.346527   54.346527  18393200
# 3     2004-08-24   55.260582   55.439419  ...   52.096165   52.096165  15361800
# 4     2004-08-25   52.140873   53.651051  ...   52.657513   52.657513   9257400
# ...          ...         ...         ...  ...         ...         ...       ...
# 3308  2017-10-09  980.000000  985.424988  ...  977.000000  977.000000    891400
# 3309  2017-10-10  980.000000  981.570007  ...  972.599976  972.599976    968400
# 3310  2017-10-11  973.719971  990.710022  ...  989.250000  989.250000   1693300
# 3311  2017-10-12  987.450012  994.119995  ...  987.830017  987.830017   1262400
# 3312  2017-10-13  992.000000  997.210022  ...  989.679993  989.679993   1157700
#
# [3313 rows x 7 columns]

# %%
df.to_csv("name_of_the_new_file.csv","location")

# %%
df['Open'].nunique()
# Out:
# 3208

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3313 non-null   object
#  1   Open       3313 non-null   float64
#  2   High       3313 non-null   float64
#  3   Low        3313 non-null   float64
#  4   Close      3313 non-null   float64
#  5   Adj Close  3313 non-null   float64
#  6   Volume     3313 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 181.3+ KB

# %%
type(df)
String
GroupBY
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv('population_india_census2011.csv')

# %%
df
# Out:
#     Sno  ... Gender Ratio
# 0     1  ...          912
# 1     2  ...          929
# 2     3  ...          918
# 3     4  ...          953
# 4     5  ...          931
# 5     6  ...          996
# 6     7  ...          928
# 7     8  ...          973
# 8     9  ...          919
# 9    10  ...          993
# 10   11  ...          979
# 11   12  ...          988
# 12   13  ...         1084
# 13   14  ...          948
# 14   15  ...          954
# 15   16  ...          895
# 16   17  ...          991
# 17   18  ...          879
# 18   19  ...          963
# 19   20  ...          972
# 20   21  ...          960
# 21   22  ...          989
# 22   23  ...          992
# 23   24  ...          931
# 24   25  ...          973
# 25   26  ...          938
# 26   27  ...          976
# 27   28  ...          890
# 28   29  ...          868
# 29   30  ...          890
# 30   31  ...         1037
# 31   32  ...          818
# 32   33  ...          711
# 33   34  ...          876
# 34   35  ...          853
# 35   36  ...          946
#
# [36 rows x 8 columns]

# %%
virtualenv venv
source venv/bin/activate
cd venv/bin/ -> activate
deactivate

# %%
df.loc[,]
