# %% [markdown]
# # Revision

# %%
Names = []
Games =["pubg"," candy crush"]

# %%
Names.append("sayali")

# %%
Names
# Out:
# ['sayali']

# %%
Names.extend(Names)

# %%
Names
# Out:
# ['sayali', 'sayali']

# %%
name = "Monty Python"
name[::-1]
# Out:
# 'Monty Python'

# %%
elec =  ["Computer","Phone","iPhone","iPad","Microphone","Speaker","Earplugs"]

# %%
del elec[-1]

# Error
#

# %%
elec = []
ele = list()
# Out:
# ['Computer', 'Phone', 'iPhone', 'iPad', 'Microphone', 'Speaker']

# %%
w = [9,34,777,576,34,0,0.5,3,56,98,23,67,0.1,9]
min(w)
# Out:
# 0

# %%
lis = [[[7,[5]]],[[1,[2,[3,4,[5,[9,8]]]]]]]

# %%
lis[1][0][1][1][2][1].remove()
# Out:
# [5, []]

# %%
lis
# Out:
# [[[7, [5]]], [[1, [2, [3, 4, [5, []]]]]]]

# %%
a = "Hello Hola Hey Hi"
a[0:-1:2]

# 'HloHl e '
# loHl e H
# Out:
# 'HloHl e '

# %%
list1 = [1,2,3,4]
list2 = [5,6,7,8]
list1 = list1 + list2
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list1
# Out:
# [1, 2, 3, 4]

# %%
lis = ["apples", "mangoes","cherry"]

# %%
clear()
#  It removes all the elements from the list

# %%
lis.clear()

# %%
lis
# Out:
# []

# %%
listi = lis.copy()
listi
# Out:
# ['apples', 'mangoes', 'cherry']

# %%
copy()

# %%
listi
# Out:
# []

# %%
kite = [1,2,3,4,5,6,1,2,1,1,2]

# %%
kite.count(3)
# Out:
# 1

# %% [markdown]
# # Tuple
#
# 1. Python Data Structure
# 2. Immutable -> Unchangable
# 3. ()
# 4. It allows the Duplicacy

# %%
abd = {'w': 1, '3': 1, 'r': 2, 'e': 2, 's': 1, 'o': 1, 'u': 1, 'c': 1}

# %%
abd.fromkeys
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-4788fb47348f> in <module>()
# ----> 1 abd.item()
#
# AttributeError: 'dict' object has no attribute 'item'

# %%
x = ('AWS', 'GCP', 'Azure', 'Heroku')
y = 'Cloud'
thisdict = dict.fromkeys(x, y)
print(thisdict)
# Out:
# {'AWS': 'Cloud', 'GCP': 'Cloud', 'Azure': 'Cloud', 'Heroku': 'Cloud'}

# %%
lis.items()
# Out:
# dict_items([('a', 'A'), ('b', 'B')])
